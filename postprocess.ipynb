# %%
from pathlib import Path

cities = [
    "adana",
    "ankara",
    "antalya",
    "antep",
    "bursa",
    "diyarbakır",
    "istanbul",
    "izmir",
    "kayseri",
    "konya",
    "mersin",
]

data_dirs = [Path(city) for city in cities]
data_dirs
# Out:
# [WindowsPath('adana'),
#  WindowsPath('ankara'),
#  WindowsPath('antalya'),
#  WindowsPath('antep'),
#  WindowsPath('bursa'),
#  WindowsPath('diyarbakır'),
#  WindowsPath('istanbul'),
#  WindowsPath('izmir'),
#  WindowsPath('kayseri'),
#  WindowsPath('konya'),
#  WindowsPath('mersin')]

# %%
import json
from functools import reduce

def read_json_from_dir(dir_path, city_name):
    data = []
    i = 0
    for path in dir_path.glob("*.json"):
        with path.open("r", encoding="utf-8") as f:
            content = json.load(f)
        assert type(content) is list
        for item in content:
            item["id"] = f"{city_name}_{i}"
            i += 1
            data.append(item)
    return data
    

json_files = [
    read_json_from_dir(dd, dd.name)
    for dd in data_dirs
]
json_files = reduce(lambda a, b: a + b, json_files)
json_files
# Out:
# [{'id': 'adana_0',
#   'name': 'Sabancı Merkez Camii',
#   'category': ['Cami', 'Tarihi'],
#   'coordinates': {'lat': 36.9955, 'lng': 35.325},
#   'city': 'Adana',
#   'district': 'Seyhan',
#   'average_stay_minutes': 60,
#   'average_spend': {'amount': 0, 'currency': 'TRY'},
#   'best_visit_times': {'season': ['İlkbahar', 'Sonbahar'],
#    'days': ['Salı', 'Perşembe'],
#    'hours': ['09:00-19:00']},
#   'tags': ['dini', 'ikonik', 'nehir kenarı'],
#   'popularity_score': 95,
#   'virality_trend': 'yükselişte',
#   'average_rating': 4.8,
#   'review_count': 8200,
#   'sources': ['Tripadvisor', 'Ekşi Sözlük'],
#   'photos': []},
#  {'id': 'adana_1',
#   'name': 'Taşköprü',
#   'category': ['Anıt', 'Tarihi'],
#   'coordinates': {'lat': 36.9856, 'lng': 35.3253},
#   'city': 'Adana',
#   'district': 'Seyhan',
#   'average_stay_minutes': 30,
#   'average_spend': {'amount': 0, 'currency': 'TRY'},
#   'best_visit_times': {'season': ['Tüm yıl'],
#    'days': ['Hafta içi'],
#    'hours': ['08:00-22:00']},
#   'tags': ['roma köprüsü', 'fotoğraf', 'gün batımı'],
#   'popularity_score': 92,
#   'virality_trend': 'stabil',
#   'average_rating': 4.7,
#   'review_count': 6100,
#   'sources': ['Tripadvisor'],
#   'photos': []},
#  {'id': 'adana_2',
#   'name': 'Merkez Park',
#   'category': ['Park', 'Doğal'],
#   'coordinates': {'lat': 36.995, 'lng': 35.328},
#   'city': 'Adana',
#   'district': 'Seyhan',
#   'average_stay_minutes': 90,
#   'average_spend': {'amount': 0, 'currency': 'TRY'},
#   'best_visit_times': {'season': ['İlkbahar', 'Yaz', 'Sonbahar'],
#    'days': ['Cumartesi', 'Pazar'],
#    'hours': ['09:00-20:00']},
#   'tags': ['yürüyüş', 'piknik', 'seyir'],
#   'popularity_score': 88,
#   'virality_trend': 'stabil',
#   'average_rating': 4.5,
#   'review_count': 4300,
#   'sources': ['Tripadvisor', 'Foursquare'],
#   'photos': []},
#  {'id': 'adana_3',
#   'name': 'Adana Müze Kompleksi (Arkeoloji Müzesi)',
#   'category': ['Müze', 'Tarih'],
#   'coordinates': {'lat': 36.9837, 'lng': 35.3089},
#   'city': 'Adana',
#   'district': 'Seyhan',
#   'average_stay_minutes': 120,
#   'average_spend': {'amount': 200, 'currency': 'TRY'},
#   'best_visit_times': {'season': ['Tüm yıl'],
#    'days': ['Salı', 'Perşembe'],
#    'hours': ['10:00-17:00']},
#   'tags': ['arkeoloji', 'koleksiyon'],
#   'popularity_score': 86,
#   'virality_trend': 'stabil',
#   'average_rating': 4.6,
#   'review_count': 2100,
#   'sources': ['Tripadvisor'],
#   'photos': []},
#  {'id': 'adana_4',
#   'name': 'Adana Ulu Camii',
#   'category': ['Cami', 'Tarihi'],
#   'coordinates': {'lat': 36.9834, 'lng': 35.3312},
#   'city': 'Adana',
#   'district': 'Seyhan',
#   'average_stay_minutes': 45,
#   'average_spend': {'amount': 0, 'currency': 'TRY'},
#   'best_visit_times': {'season': ['Tüm yıl'],
#    'days': ['Hafta içi'],
#    'hours': ['09:00-18:00']},
#   'tags': ['memlük', 'selçuklu', 'mimari'],
#   'popularity_score': 84,
#   'virality_trend': 'stabil',
#   'average_rating': 4.6,
#   'review_count': 1900,
#   'sources': ['Tripadvisor'],
#   'photos': []},
#  {'id': 'adana_5',
#   'name': 'Büyük Saat Kulesi',
#   'category': ['Anıt', 'Tarihi'],
#   'coordinates': {'lat': 36.9859, 'lng': 35.3259},
#   'city': 'Adana',
#   'district': 'Seyhan',
#   'average_stay_minutes': 20,
#   'average_spend': {'amount': 0, 'currency': 'TRY'},
#   'best_visit_times': {'season': ['Tüm yıl'],
#    'days': ['Cumartesi', 'Pazar'],
#    'hours': ['09:00-21:00']},
#   'tags': ['sembol', 'tarihi çarşı'],
#   'popularity_score': 83,
#   'virality_trend': 'stabil',
#   'average_rating': 4.4,
#   'review_count': 2500,
#   'sources': ['Tripadvisor'],
#   'photos': []},
#  {'id': 'adana_6',
#   'name': 'Kazancılar Çarşısı',
#   'category': ['Çarşı', 'Yeme-İçme'],
#   'coordinates': {'lat': 36.9839, 'lng': 35.329},
#   'city': 'Adana',
#   'district': 'Seyhan',
#   'average_stay_minutes': 90,
#   'average_spend': {'amount': 250, 'currency': 'TRY'},
#   'best_visit_times': {'season': ['Tüm yıl'],
#    'days': ['Cuma', 'Cumartesi'],
#    'hours': ['10:00-20:00']},
#   'tags': ['kebap', 'tatlı', 'alışveriş'],
#   'popularity_score': 85,
#   'virality_trend': 'yükselişte',
#   'average_rating': 4.5,
#   'review_count': 3300,
#   'sources': ['Foursquare', 'Ekşi Sözlük'],
#   'photos': []},
#  {'id': 'adana_7',
#   'name': 'Adana Sinema Müzesi',
#   'category': ['Müze', 'Kültür'],
#   'coordinates': {'lat': 36.9969, 'lng': 35.3275},
#   'city': 'Adana',
#   'district': 'Seyhan',
#   'average_stay_minutes': 60,
#   'average_spend': {'amount': 100, 'currency': 'TRY'},
#   'best_visit_times': {'season': ['Tüm yıl'],
#    'days': ['Cumartesi', 'Pazar'],
#    'hours': ['10:00-18:00']},
#   'tags': ['sinema', 'kültür', 'sergi'],
#   'popularity_score': 80,
#   'virality_trend': 'stabil',
#   'average_rating': 4.4,
#   'review_count': 1400,
#   'sources': ['Tripadvisor'],
#   'photos': []},
#  {'id': 'adana_8',
#   'name': 'Dilberler Sekisi',
#   'category': ['Park', 'Sahil'],
#   'coordinates': {'lat': 37.001, 'lng': 35.31},
#   'city': 'Adana',
#   'district': 'Seyhan',
#   'average_stay_minutes': 60,
#   'average_spend': {'amount': 0, 'currency': 'TRY'},
#   'best_visit_times': {'season': ['İlkbahar', 'Yaz', 'Sonbahar'],
#    'days': ['Hafta sonu'],
#    'hours': ['09:00-20:00']},
#   'tags': ['seyhan nehri', 'yürüyüş', 'bisiklet'],
#   'popularity_score': 79,
#   'virality_trend': 'stabil',
#   'average_rating': 4.3,
#   'review_count': 1600,
#   'sources': ['Foursquare'],
#   'photos': []},
#  {'id': 'adana_9',
#   'name': 'Seyhan Baraj Gölü - Çoban Dede',
#   'category': ['Manzara', 'Doğal'],
#   'coordinates': {'lat': 37.0357, 'lng': 35.2896},
#   'city': 'Adana',
#   'district': 'Çukurova',
#   'average_stay_minutes': 120,
#   'average_spend': {'amount': 50, 'currency': 'TRY'},
#   'best_visit_times': {'season': ['İlkbahar', 'Yaz'],
#    'days': ['Cumartesi', 'Pazar'],
#    'hours': ['10:00-19:00']},
#   'tags': ['manzara', 'piknik', 'fotoğraf'],
#   'popularity_score': 82,
#   'virality_trend': 'stabil',
#   'average_rating': 4.4,
#   'review_count': 2200,
#   'sources': ['Foursquare'],
#   'photos': []},
#  {'id': 'adana_10',
#   'name': 'Çukurova Üniversitesi Kampüsü (Balcalı)',
#   'category': ['Kampüs', 'Park'],
#   'coordinates': {'lat': 36.9996, 'lng': 35.355},
#   'city': 'Adana',
#   'district': 'Sarıçam',
#   'average_stay_minutes': 90,
#   'average_spend': {'amount': 0, 'currency': 'TRY'},
#   'best_visit_times': {'season': ['İlkbahar', 'Sonbahar'],
#    'days': ['Hafta içi'],
#    'hours': ['09:00-18:00']},
#   'tags': ['yeşil alan', 'göl', 'yürüyüş'],
#   'popularity_score': 77,
#   'virality_trend': 'stabil',
#   'average_rating': 4.4,
#   'review_count': 1300,
#   'sources': ['Foursquare'],
#   'photos': []},
#  {'id': 'adana_11',
#   'name': '01 Burda AVM',
#   'category': ['AVM', 'Alışveriş'],
#   'coordinates': {'lat': 36.9897, 'lng': 35.2976},
#   'city': 'Adana',
#   'district': 'Seyhan',
#   'average_stay_minutes': 120,
#   'average_spend': {'amount': 400, 'currency': 'TRY'},
#   'best_visit_times': {'season': ['Tüm yıl'],
#    'days': ['Hafta içi'],
#    'hours': ['10:00-22:00']},
#   'tags': ['alışveriş', 'yeme-içme', 'sinema'],
#   'popularity_score': 78,
#   'virality_trend': 'stabil',
#   'average_rating': 4.3,
#   'review_count': 2400,
#   'sources': ['Foursquare'],
#   'photos': []},
#  {'id': 'adana_12',
#   'name': 'M1 Adana AVM',
#   'category': ['AVM', 'Alışveriş'],
#   'coordinates': {'lat': 36.9742, 'lng': 35.2707},
#   'city': 'Adana',
#   'district': 'Yüreğir',
#   'average_stay_minutes': 110,
#   'average_spend': {'amount': 350, 'currency': 'TRY'},
#   'best_visit_times': {'season': ['Tüm yıl'],
#    'days': ['Cumartesi', 'Pazar'],
#    'hours': ['10:00-22:00']},
#   'tags': ['alışveriş', 'aile'],
#   'popularity_score': 76,
#   'virality_trend': 'stabil',
#   'average_rating': 4.2,
#   'review_count': 2100,
#   'sources': ['Foursquare'],
#   'photos': []},
#  {'id': 'adana_13',
#   'name': 'Adana Optimum AVM',
#   'category': ['AVM', 'Alışveriş'],
#   'coordinates': {'lat': 36.9906, 'lng': 35.3612},
#   'city': 'Adana',
#   'district': 'Yüreğir',
#   'average_stay_minutes': 120,
#   'average_spend': {'amount': 450, 'currency': 'TRY'},
#   'best_visit_times': {'season': ['Tüm yıl'],
#    'days': ['Hafta içi'],
#    'hours': ['10:00-22:00']},
#   'tags': ['alışveriş', 'eğlence'],
#   'popularity_score': 77,
#   'virality_trend': 'stabil',
#   'average_rating': 4.3,
#   'review_count': 2200,
#   'sources': ['Foursquare'],
#   'photos': []},
#  {'id': 'adana_14',
#   'name': 'Varda (Alman) Köprüsü',
#   'category': ['Anıt', 'Manzara'],
#   'coordinates': {'lat': 37.2508, 'lng': 34.9955},
#   'city': 'Adana',
#   'district': 'Karaisalı',
#   'average_stay_minutes': 60,
#   'average_spend': {'amount': 50, 'currency': 'TRY'},
#   'best_visit_times': {'season': ['İlkbahar', 'Sonbahar'],
#    'days': ['Cumartesi', 'Pazar'],
#    'hours': ['10:00-18:00']},
#   'tags': ['köprü', 'doğa', 'fotoğraf'],
#   'popularity_score': 88,
#   'virality_trend': 'yükselişte',
#   'average_rating': 4.7,
#   'review_count': 3500,
#   'sources': ['Tripadvisor'],
#   'photos': []},
#  {'id': 'adana_15',
#   'name': 'Kapıkaya Kanyonu',
#   'category': ['Doğal', 'Macera'],
#   'coordinates': {'lat': 37.2384, 'lng': 35.0492},
#   'city': 'Adana',
#   'district': 'Karaisalı',
#   'average_stay_minutes': 150,
#   'average_spend': {'amount': 100, 'currency': 'TRY'},
#   'best_visit_times': {'season': ['İlkbahar', 'Yaz'],
#    'days': ['Cumartesi'],
#    'hours': ['09:00-17:00']},
#   'tags': ['yürüyüş', 'kanyon', 'fotoğraf'],
#   'popularity_score': 84,
#   'virality_trend': 'yükselişte',
#   'average_rating': 4.6,
#   'review_count': 1900,
#   'sources': ['Tripadvisor', 'Foursquare'],
#   'photos': []},
#  {'id': 'adana_16',
#   'name': 'Belemedik Tabiat Parkı',
#   'category': ['Doğal', 'Park'],
#   'coordinates': {'lat': 37.4615, 'lng': 34.9077},
#   'city': 'Adana',
#   'district': 'Pozantı',
#   'average_stay_minutes': 180,
#   'average_spend': {'amount': 150, 'currency': 'TRY'},
#   'best_visit_times': {'season': ['İlkbahar', 'Sonbahar'],
#    'days': ['Hafta sonu'],
#    'hours': ['09:00-18:00']},
#   'tags': ['piknik', 'doğa', 'fotoğraf'],
#   'popularity_score': 83,
#   'virality_trend': 'stabil',
#   'average_rating': 4.5,
#   'review_count': 1700,
#   'sources': ['Tripadvisor'],
#   'photos': []},
#  {'id': 'adana_17',
#   'name': 'Yumurtalık Lagünü Milli Parkı',
#   'category': ['Doğal', 'Kuş Gözlemi'],
#   'coordinates': {'lat': 36.774, 'lng': 35.686},
#   'city': 'Adana',
#   'district': 'Yumurtalık',
#   'average_stay_minutes': 150,
#   'average_spend': {'amount': 50, 'currency': 'TRY'},
#   'best_visit_times': {'season': ['Kış', 'İlkbahar'],
#    'days': ['Hafta içi'],
#    'hours': ['08:00-17:00']},
#   'tags': ['kuş', 'doğa', 'fotoğraf'],
#   'popularity_score': 82,
#   'virality_trend': 'stabil',
#   'average_rating': 4.5,
#   'review_count': 1200,
#   'sources': ['Tripadvisor'],
#   'photos': []},
#  {'id': 'adana_18',
#   'name': 'Yumurtalık Ayas Kalesi',
#   'category': ['Tarihi', 'Sahil'],
#   'coordinates': {'lat': 36.7781, 'lng': 35.7831},
#   'city': 'Adana',
#   'district': 'Yumurtalık',
#   'average_stay_minutes': 60,
#   'average_spend': {'amount': 20, 'currency': 'TRY'},
#   'best_visit_times': {'season': ['Yaz', 'İlkbahar'],
#    'days': ['Cumartesi', 'Pazar'],
#    'hours': ['10:00-19:00']},
#   'tags': ['kale', 'sahil', 'fotoğraf'],
#   'popularity_score': 80,
#   'virality_trend': 'stabil',
#   'average_rating': 4.3,
#   'review_count': 1400,
#   'sources': ['Tripadvisor'],
#   'photos': []},
#  {'id': 'adana_19',
#   'name': 'Misis Mozaik Müzesi',
#   'category': ['Müze', 'Tarih'],
#   'coordinates': {'lat': 36.9936, 'lng': 35.6832},
#   'city': 'Adana',
#   'district': 'Yüreğir',
#   'average_stay_minutes': 75,
#   'average_spend': {'amount': 100, 'currency': 'TRY'},
#   'best_visit_times': {'season': ['Tüm yıl'],
#    'days': ['Hafta içi'],
#    'hours': ['10:00-17:00']},
#   'tags': ['mozaik', 'antik', 'arkeoloji'],
#   'popularity_score': 79,
#   'virality_trend': 'stabil',
#   'average_rating': 4.4,
#   'review_count': 1100,
#   'sources': ['Tripadvisor'],
#   'photos': []},
#  {'id': 'adana_20',
#   'name': 'Anavarza Antik Kenti',
#   'category': ['Tarihi', 'Açıkhava'],
#   'coordinates': {'lat': 37.2572, 'lng': 35.8975},
#   'city': 'Adana',
#   'district': 'Kozan',
#   'average_stay_minutes': 150,
#   'average_spend': {'amount': 200, 'currency': 'TRY'},
#   'best_visit_times': {'season': ['İlkbahar', 'Sonbahar'],
#    'days': ['Cumartesi'],
#    'hours': ['09:00-17:00']},
#   'tags': ['antik kent', 'kale', 'arkeoloji'],
#   'popularity_score': 85,
#   'virality_trend': 'yükselişte',
#   'average_rating': 4.6,
#   'review_count': 2000,
#   'sources': ['Tripadvisor'],
#   'photos': []},
#  {'id': 'adana_21',
#   'name': 'Kozan Kalesi',
#   'category': ['Tarihi', 'Manzara'],
#   'coordinates': {'lat': 37.4431, 'lng': 35.8155},
#   'city': 'Adana',
#   'district': 'Kozan',
#   'average_stay_minutes': 60,
#   'average_spend': {'amount': 0, 'currency': 'TRY'},
#   'best_visit_times': {'season': ['İlkbahar', 'Sonbahar'],
#    'days': ['Hafta sonu'],
#    'hours': ['10:00-18:00']},
#   'tags': ['kale', 'panoramik', 'tarih'],
#   'popularity_score': 80,
#   'virality_trend': 'stabil',
#   'average_rating': 4.4,
#   'review_count': 1500,
#   'sources': ['Tripadvisor'],
#   'photos': []},
#  {'id': 'adana_22',
#   'name': 'Karataş Plajı',
#   'category': ['Plaj', 'Doğal'],
#   'coordinates': {'lat': 36.567, 'lng': 35.377},
#   'city': 'Adana',
#   'district': 'Karataş',
#   'average_stay_minutes': 180,
#   'average_spend': {'amount': 150, 'currency': 'TRY'},
#   'best_visit_times': {'season': ['Yaz', 'İlkbahar'],
#    'days': ['Cumartesi', 'Pazar'],
#    'hours': ['09:00-19:00']},
#   'tags': ['deniz', 'kum', 'aile'],
#   'popularity_score': 78,
#   'virality_trend': 'stabil',
#   'average_rating': 4.2,
#   'review_count': 1700,
#   'sources': ['Foursquare'],
#   'photos': []},
#  {'id': 'ankara_0',
#   'name': 'Anıtkabir',
#   'category': ['Tarihi', 'Anıt'],
#   'coordinates': {'lat': 39.9251, 'lng': 32.8369},
#   'city': 'Ankara',
#   'district': 'Çankaya',
#   'average_stay_minutes': 120,
#   'average_spend': {'amount': 0, 'currency': 'TRY'},
#   'best_visit_times': {'season': ['İlkbahar', 'Sonbahar'],
#    'days': ['Hafta içi'],
#    'hours': ['09:00-17:00']},
#   'tags': ['atatürk', 'anıt', 'tarihi'],
#   'popularity_score': 99,
#   'virality_trend': 'yükselişte',
#   'average_rating': 4.9,
#   'review_count': 150000,
#   'sources': ['Google Maps', 'Tripadvisor'],
#   'photos': ['https://maps.googleapis.com/photo/ankara_anitkabir1',
#    'https://instagram.com/anitkabir.jpg']},
#  {'id': 'ankara_1',
#   'name': 'Anadolu Medeniyetleri Müzesi',
#   'category': ['Müze', 'Tarihi'],
#   'coordinates': {'lat': 39.9391, 'lng': 32.8612},
#   'city': 'Ankara',
#   'district': 'Ulus',
#   'average_stay_minutes': 150,
#   'average_spend': {'amount': 75, 'currency': 'TRY'},
#   'best_visit_times': {'season': ['İlkbahar', 'Yaz'],
#    'days': ['Salı', 'Çarşamba', 'Cuma'],
#    'hours': ['10:00-17:00']},
#   'tags': ['arkeoloji', 'müze', 'tarihi'],
#   'popularity_score': 92,
#   'virality_trend': 'stabil',
#   'average_rating': 4.8,
#   'review_count': 24000,
#   'sources': ['Google Maps', 'Instagram'],
#   'photos': ['https://maps.googleapis.com/photo/anadolu_medeniyetleri',
#    'https://instagram.com/anadolu_muzesi.jpg']},
#  {'id': 'ankara_2',
#   'name': 'Kuğulu Park',
#   'category': ['Park', 'Doğa'],
#   'coordinates': {'lat': 39.9092, 'lng': 32.8597},
#   'city': 'Ankara',
#   'district': 'Çankaya',
#   'average_stay_minutes': 60,
#   'average_spend': {'amount': 20, 'currency': 'TRY'},
#   'best_visit_times': {'season': ['İlkbahar', 'Yaz'],
#    'days': ['Cumartesi', 'Pazar'],
#    'hours': ['08:00-22:00']},
#   'tags': ['aile dostu', 'doğa', 'park'],
#   'popularity_score': 85,
#   'virality_trend': 'yükselişte',
#   'average_rating': 4.5,
#   'review_count': 18000,
#   'sources': ['Google Maps'],
#   'photos': ['https://maps.googleapis.com/photo/kugulupark',
#    'https://instagram.com/kugulupark.jpg']},
#  {'id': 'ankara_3',
#   'name': 'CerModern',
#   'category': ['Sanat', 'Kültür'],
#   'coordinates': {'lat': 39.9335, 'lng': 32.8511},
#   'city': 'Ankara',
#   'district': 'Sıhhiye',
#   'average_stay_minutes': 100,
#   'average_spend': {'amount': 60, 'currency': 'TRY'},
#   'best_visit_times': {'season': ['İlkbahar', 'Sonbahar'],
#    'days': ['Cuma', 'Cumartesi'],
#    'hours': ['10:00-20:00']},
#   'tags': ['sanat', 'sergi', 'modern'],
#   'popularity_score': 80,
#   'virality_trend': 'stabil',
#   'average_rating': 4.6,
#   'review_count': 5000,
#   'sources': ['Google Maps', 'Instagram'],
#   'photos': ['https://maps.googleapis.com/photo/cermodern',
#    'https://instagram.com/cermodern.jpg']},
#  {'id': 'ankara_4',
#   'name': 'Eymir Gölü',
#   'category': ['Doğa', 'Göl'],
#   'coordinates': {'lat': 39.8706, 'lng': 32.8024},
#   'city': 'Ankara',
#   'district': 'Gölbaşı',
#   'average_stay_minutes': 180,
#   'average_spend': {'amount': 50, 'currency': 'TRY'},
#   'best_visit_times': {'season': ['İlkbahar', 'Yaz', 'Sonbahar'],
#    'days': ['Cumartesi', 'Pazar'],
#    'hours': ['08:00-21:00']},
#   'tags': ['doğa', 'piknik', 'bisiklet'],
#   'popularity_score': 90,
#   'virality_trend': 'yükselişte',
#   'average_rating': 4.7,
#   'review_count': 12000,
#   'sources': ['Google Maps', 'Instagram'],
#   'photos': ['https://maps.googleapis.com/photo/eymirgol',
#    'https://instagram.com/eymirgol.jpg']},
#  {'id': 'ankara_5',
#   'name': 'Atatürk Orman Çiftliği',
#   'category': ['Doğa', 'Tarihi'],
#   'coordinates': {'lat': 39.95, 'lng': 32.8},
#   'city': 'Ankara',
#   'district': 'Yenimahalle',
#   'average_stay_minutes': 120,
#   'average_spend': {'amount': 70, 'currency': 'TRY'},
#   'best_visit_times': {'season': ['İlkbahar', 'Sonbahar'],
#    'days': ['Hafta sonu'],
#    'hours': ['09:00-19:00']},
#   'tags': ['çiftlik', 'doğa', 'tarihi'],
#   'popularity_score': 88,
#   'virality_trend': 'stabil',
#   'average_rating': 4.6,
#   'review_count': 15000,
#   'sources': ['Google Maps'],
#   'photos': ['https://maps.googleapis.com/photo/aoc',
#    'https://instagram.com/aoc.jpg']},
#  {'id': 'ankara_6',
#   'name': 'Gençlik Parkı',
#   'category': ['Park', 'Eğlence'],
#   'coordinates': {'lat': 39.9415, 'lng': 32.8541},
#   'city': 'Ankara',
#   'district': 'Altındağ',
#   'average_stay_minutes': 120,
#   'average_spend': {'amount': 30, 'currency': 'TRY'},
#   'best_visit_times': {'season': ['Yaz'],
#    'days': ['Cumartesi', 'Pazar'],
#    'hours': ['09:00-23:00']},
#   'tags': ['eğlence', 'park', 'çocuklu aile'],
#   'popularity_score': 83,
#   'virality_trend': 'yükselişte',
#   'average_rating': 4.4,
#   'review_count': 11000,
#   'sources': ['Google Maps'],
#   'photos': ['https://maps.googleapis.com/photo/genclikpark',
#    'https://instagram.com/genclikpark.jpg']},
#  {'id': 'ankara_7',
#   'name': 'Rahmi Koç Müzesi Ankara',
#   'category': ['Müze', 'Tarihi'],
#   'coordinates': {'lat': 39.9469, 'lng': 32.853},
#   'city': 'Ankara',
#   'district': 'Altındağ',
#   'average_stay_minutes': 120,
#   'average_spend': {'amount': 60, 'currency': 'TRY'},
#   'best_visit_times': {'season': ['İlkbahar', 'Kış'],
#    'days': ['Çarşamba', 'Perşembe', 'Cuma'],
#    'hours': ['09:30-17:30']},
#   'tags': ['sanayi', 'tarih', 'çocuk dostu'],
#   'popularity_score': 86,
#   'virality_trend': 'stabil',
#   'average_rating': 4.7,
#   'review_count': 8000,
#   'sources': ['Google Maps', 'Instagram'],
#   'photos': ['https://maps.googleapis.com/photo/rahmikocankara',
#    'https://instagram.com/rahmikocankara.jpg']},
#  {'id': 'ankara_8',
#   'name': 'Augustus Tapınağı',
#   'category': ['Tarihi', 'Arkeolojik'],
#   'coordinates': {'lat': 39.9425, 'lng': 32.8625},
#   'city': 'Ankara',
#   'district': 'Ulus',
#   'average_stay_minutes': 45,
#   'average_spend': {'amount': 0, 'currency': 'TRY'},
#   'best_visit_times': {'season': ['İlkbahar', 'Yaz'],
#    'days': ['Hafta içi'],
#    'hours': ['09:00-17:00']},
#   'tags': ['arkeoloji', 'tarih', 'açık hava'],
#   'popularity_score': 75,
#   'virality_trend': 'stabil',
#   'average_rating': 4.2,
#   'review_count': 3000,
#   'sources': ['Google Maps'],
#   'photos': ['https://maps.googleapis.com/photo/augustus',
#    'https://instagram.com/augustus.jpg']},
#  {'id': 'ankara_9',
#   'name': 'Kocatepe Camii',
#   'category': ['Dini', 'Mimari'],
#   'coordinates': {'lat': 39.9212, 'lng': 32.8541},
#   'city': 'Ankara',
#   'district': 'Kocatepe',
#   'average_stay_minutes': 60,
#   'average_spend': {'amount': 0, 'currency': 'TRY'},
#   'best_visit_times': {'season': ['Tüm yıl'],
#    'days': ['Her gün'],
#    'hours': ['Gün boyu']},
#   'tags': ['ibadet', 'camii', 'mimari'],
#   'popularity_score': 91,
#   'virality_trend': 'stabil',
#   'average_rating': 4.8,
#   'review_count': 21000,
#   'sources': ['Google Maps'],
#   'photos': ['https://maps.googleapis.com/photo/kocatepe',
#    'https://instagram.com/kocatepe.jpg']},
#  {'id': 'ankara_10',
#   'name': 'Hamamönü',
#   'category': ['Tarihi', 'Kültürel'],
#   'coordinates': {'lat': 39.9345, 'lng': 32.8681},
#   'city': 'Ankara',
#   'district': 'Altındağ',
#   'average_stay_minutes': 120,
#   'average_spend': {'amount': 120, 'currency': 'TRY'},
#   'best_visit_times': {'season': ['İlkbahar', 'Sonbahar'],
#    'days': ['Cumartesi', 'Pazar'],
#    'hours': ['10:00-22:00']},
#   'tags': ['osmanlı', 'kültür', 'yeme içme'],
#   'popularity_score': 89,
#   'virality_trend': 'yükselişte',
#   'average_rating': 4.6,
#   'review_count': 17500,
#   'sources': ['Google Maps', 'Instagram'],
#   'photos': ['https://maps.googleapis.com/photo/hamamonu',
#    'https://instagram.com/hamamonu.jpg']},
#  {'id': 'ankara_11',
#   'name': 'Kale İçi',
#   'category': ['Tarihi', 'Gezi'],
#   'coordinates': {'lat': 39.9411, 'lng': 32.8627},
#   'city': 'Ankara',
#   'district': 'Altındağ',
#   'average_stay_minutes': 90,
#   'average_spend': {'amount': 80, 'currency': 'TRY'},
#   'best_visit_times': {'season': ['İlkbahar', 'Yaz'],
#    'days': ['Her gün'],
#    'hours': ['09:00-20:00']},
#   'tags': ['kale', 'tarihi', 'manzara'],
#   'popularity_score': 84,
#   'virality_trend': 'stabil',
#   'average_rating': 4.5,
#   'review_count': 9500,
#   'sources': ['Google Maps'],
#   'photos': ['https://maps.googleapis.com/photo/kaleici',
#    'https://instagram.com/kaleici.jpg']},
#  {'id': 'ankara_12',
#   'name': 'Atakule',
#   'category': ['Manzara', 'Alışveriş'],
#   'coordinates': {'lat': 39.8949, 'lng': 32.8608},
#   'city': 'Ankara',
#   'district': 'Çankaya',
#   'average_stay_minutes': 100,
#   'average_spend': {'amount': 150, 'currency': 'TRY'},
#   'best_visit_times': {'season': ['Yaz', 'Sonbahar'],
#    'days': ['Cumartesi', 'Pazar'],
#    'hours': ['10:00-22:00']},
#   'tags': ['manzara', 'alışveriş', 'restoran'],
#   'popularity_score': 88,
#   'virality_trend': 'yükselişte',
#   'average_rating': 4.6,
#   'review_count': 13000,
#   'sources': ['Google Maps', 'Instagram'],
#   'photos': ['https://maps.googleapis.com/photo/atakule',
#    'https://instagram.com/atakule.jpg']},
#  {'id': 'ankara_13',
#   'name': 'Seğmenler Parkı',
#   'category': ['Park', 'Doğa'],
#   'coordinates': {'lat': 39.9009, 'lng': 32.8583},
#   'city': 'Ankara',
#   'district': 'Çankaya',
#   'average_stay_minutes': 90,
#   'average_spend': {'amount': 0, 'currency': 'TRY'},
#   'best_visit_times': {'season': ['İlkbahar', 'Yaz'],
#    'days': ['Hafta sonu'],
#    'hours': ['07:00-22:00']},
#   'tags': ['doğa', 'piknik', 'aile dostu'],
#   'popularity_score': 82,
#   'virality_trend': 'stabil',
#   'average_rating': 4.5,
#   'review_count': 7200,
#   'sources': ['Google Maps'],
#   'photos': ['https://maps.googleapis.com/photo/segmenler',
#    'https://instagram.com/segmenler.jpg']},
#  {'id': 'ankara_14',
#   'name': 'MTA Tabiat Tarihi Müzesi',
#   'category': ['Müze', 'Bilim'],
#   'coordinates': {'lat': 39.9203, 'lng': 32.8162},
#   'city': 'Ankara',
#   'district': 'Çankaya',
#   'average_stay_minutes': 120,
#   'average_spend': {'amount': 40, 'currency': 'TRY'},
#   'best_visit_times': {'season': ['Tüm yıl'],
#    'days': ['Çarşamba', 'Perşembe'],
#    'hours': ['09:00-17:00']},
#   'tags': ['bilim', 'doğa', 'çocuk'],
#   'popularity_score': 79,
#   'virality_trend': 'stabil',
#   'average_rating': 4.4,
#   'review_count': 6400,
#   'sources': ['Google Maps'],
#   'photos': ['https://maps.googleapis.com/photo/mta',
#    'https://instagram.com/mta.jpg']},
#  {'id': 'ankara_15',
#   'name': 'Kızılay Meydanı',
#   'category': ['Şehir', 'Alışveriş'],
#   'coordinates': {'lat': 39.9208, 'lng': 32.8541},
#   'city': 'Ankara',
#   'district': 'Çankaya',
#   'average_stay_minutes': 60,
#   'average_spend': {'amount': 100, 'currency': 'TRY'},
#   'best_visit_times': {'season': ['Tüm yıl'],
#    'days': ['Her gün'],
#    'hours': ['Gün boyu']},
#   'tags': ['merkez', 'alışveriş', 'şehir hayatı'],
#   'popularity_score': 95,
#   'virality_trend': 'yükselişte',
#   'average_rating': 4.3,
#   'review_count': 50000,
#   'sources': ['Google Maps', 'Instagram'],
#   'photos': ['https://maps.googleapis.com/photo/kizilay',
#    'https://instagram.com/kizilay.jpg']},
#  {'id': 'ankara_16',
#   'name': 'Aqua Vega Akvaryum',
#   'category': ['Eğlence', 'Akvaryum'],
#   'coordinates': {'lat': 39.9672, 'lng': 32.7415},
#   'city': 'Ankara',
#   'district': 'Mamak',
#   'average_stay_minutes': 90,
#   'average_spend': {'amount': 85, 'currency': 'TRY'},
#   'best_visit_times': {'season': ['Yaz', 'Kış'],
#    'days': ['Cumartesi', 'Pazar'],
#    'hours': ['10:00-20:00']},
#   'tags': ['çocuk', 'eğlence', 'akvaryum'],
#   'popularity_score': 81,
#   'virality_trend': 'yükselişte',
#   'average_rating': 4.4,
#   'review_count': 9200,
#   'sources': ['Google Maps', 'Instagram'],
#   'photos': ['https://maps.googleapis.com/photo/aquavega',
#    'https://instagram.com/aquavega.jpg']},
#  {'id': 'ankara_17',
#   'name': 'Harikalar Diyarı',
#   'category': ['Eğlence', 'Park'],
#   'coordinates': {'lat': 39.9728, 'lng': 32.7354},
#   'city': 'Ankara',
#   'district': 'Sincan',
#   'average_stay_minutes': 180,
#   'average_spend': {'amount': 60, 'currency': 'TRY'},
#   'best_visit_times': {'season': ['Yaz'],
#    'days': ['Cumartesi', 'Pazar'],
#    'hours': ['09:00-23:00']},
#   'tags': ['lunapark', 'aile', 'çocuk'],
#   'popularity_score': 83,
#   'virality_trend': 'stabil',
#   'average_rating': 4.2,
#   'review_count': 10500,
#   'sources': ['Google Maps'],
#   'photos': ['https://maps.googleapis.com/photo/harikalar',
#    'https://instagram.com/harikalar.jpg']},
#  {'id': 'ankara_18',
#   'name': 'Armada AVM',
#   'category': ['Alışveriş', 'Eğlence'],
#   'coordinates': {'lat': 39.9111, 'lng': 32.7982},
#   'city': 'Ankara',
#   'district': 'Söğütözü',
#   'average_stay_minutes': 180,
#   'average_spend': {'amount': 250, 'currency': 'TRY'},
#   'best_visit_times': {'season': ['Tüm yıl'],
#    'days': ['Cumartesi', 'Pazar'],
#    'hours': ['10:00-22:00']},
#   'tags': ['alışveriş', 'sinema', 'restoran'],
#   'popularity_score': 87,
#   'virality_trend': 'yükselişte',
#   'average_rating': 4.5,
#   'review_count': 23000,
#   'sources': ['Google Maps', 'Instagram'],
#   'photos': ['https://maps.googleapis.com/photo/armada',
#    'https://instagram.com/armada.jpg']},
#  {'id': 'ankara_19',
#   'name': 'Next Level AVM',
#   'category': ['Alışveriş', 'Yeme-İçme'],
#   'coordinates': {'lat': 39.912, 'lng': 32.806},
#   'city': 'Ankara',
#   'district': 'Çankaya',
#   'average_stay_minutes': 150,
#   'average_spend': {'amount': 200, 'currency': 'TRY'},
#   'best_visit_times': {'season': ['Tüm yıl'],
#    'days': ['Cuma', 'Cumartesi', 'Pazar'],
#    'hours': ['10:00-22:00']},
#   'tags': ['alışveriş', 'lüks', 'yeme içme'],
#   'popularity_score': 84,
#   'virality_trend': 'stabil',
#   'average_rating': 4.4,
#   'review_count': 15000,
#   'sources': ['Google Maps'],
#   'photos': ['https://maps.googleapis.com/photo/nextlevel',
#    'https://instagram.com/nextlevel.jpg']},
#  {'id': 'ankara_20',
#   'name': 'Beypazarı Tarihi Evleri',
#   'category': ['Tarihi', 'Kültürel'],
#   'coordinates': {'lat': 40.1683, 'lng': 31.9211},
#   'city': 'Ankara',
#   'district': 'Beypazarı',
#   'average_stay_minutes': 180,
#   'average_spend': {'amount': 150, 'currency': 'TRY'},
#   'best_visit_times': {'season': ['İlkbahar', 'Sonbahar'],
#    'days': ['Cumartesi', 'Pazar'],
#    'hours': ['09:00-19:00']},
#   'tags': ['osmanlı', 'tarihi ev', 'gezi'],
#   'popularity_score': 91,
#   'virality_trend': 'yükselişte',
#   'average_rating': 4.8,
#   'review_count': 9800,
#   'sources': ['Google Maps', 'Instagram'],
#   'photos': ['https://maps.googleapis.com/photo/beypazari',
#    'https://instagram.com/beypazari.jpg']},
#  {'id': 'ankara_21',
#   'name': 'Trilye Balık Lokantası',
#   'category': ['Restoran', 'Gurme'],
#   'coordinates': {'lat': 39.9011, 'lng': 32.861},
#   'city': 'Ankara',
#   'district': 'Çankaya',
#   'average_stay_minutes': 120,
#   'average_spend': {'amount': 400, 'currency': 'TRY'},
#   'best_visit_times': {'season': ['Tüm yıl'],
#    'days': ['Cuma', 'Cumartesi'],
#    'hours': ['12:00-23:00']},
#   'tags': ['balık', 'lüks', 'gurme'],
#   'popularity_score': 88,
#   'virality_trend': 'stabil',
#   'average_rating': 4.7,
#   'review_count': 8700,
#   'sources': ['Google Maps', 'Instagram'],
#   'photos': ['https://maps.googleapis.com/photo/trilye',
#    'https://instagram.com/trilye.jpg']},
#  {'id': 'ankara_22',
#   'name': 'Seğmenler Sokak Kahvecileri',
#   'category': ['Kafe', 'Yeme-İçme'],
#   'coordinates': {'lat': 39.9005, 'lng': 32.859},
#   'city': 'Ankara',
#   'district': 'Çankaya',
#   'average_stay_minutes': 90,
#   'average_spend': {'amount': 60, 'currency': 'TRY'},
#   'best_visit_times': {'season': ['Sonbahar', 'Kış'],
#    'days': ['Hafta içi'],
#    'hours': ['10:00-22:00']},
#   'tags': ['kahve', 'gençlik', 'sosyalleşme'],
#   'popularity_score': 80,
#   'virality_trend': 'yükselişte',
#   'average_rating': 4.5,
#   'review_count': 4200,
#   'sources': ['Google Maps', 'Instagram'],
#   'photos': ['https://maps.googleapis.com/photo/kahve',
#    'https://instagram.com/ankarakahve.jpg']},
#  {'id': 'ankara_23',
#   'name': 'Botanik Parkı',
#   'category': ['Park', 'Doğa'],
#   'coordinates': {'lat': 39.9289, 'lng': 32.862},
#   'city': 'Ankara',
#   'district': 'Çankaya',
#   'average_stay_minutes': 90,
#   'average_spend': {'amount': 0, 'currency': 'TRY'},
#   'best_visit_times': {'season': ['İlkbahar', 'Yaz'],
#    'days': ['Her gün'],
#    'hours': ['07:00-22:00']},
#   'tags': ['botanik', 'yeşillik', 'aile'],
#   'popularity_score': 78,
#   'virality_trend': 'stabil',
#   'average_rating': 4.3,
#   'review_count': 6100,
#   'sources': ['Google Maps'],
#   'photos': ['https://maps.googleapis.com/photo/botanik',
#    'https://instagram.com/botanik.jpg']},
#  {'id': 'ankara_24',
#   'name': 'Altınpark',
#   'category': ['Park', 'Eğlence'],
#   'coordinates': {'lat': 39.972, 'lng': 32.883},
#   'city': 'Ankara',
#   'district': 'Altındağ',
#   'average_stay_minutes': 180,
#   'average_spend': {'amount': 40, 'currency': 'TRY'},
#   'best_visit_times': {'season': ['Yaz'],
#    'days': ['Cumartesi', 'Pazar'],
#    'hours': ['09:00-23:00']},
#   'tags': ['lunapark', 'çocuk', 'göl'],
#   'popularity_score': 82,
#   'virality_trend': 'yükselişte',
#   'average_rating': 4.2,
#   'review_count': 7200,
#   'sources': ['Google Maps'],
#   'photos': ['https://maps.googleapis.com/photo/altinpark',
#    'https://instagram.com/altinpark.jpg']},
#  {'id': 'ankara_25',
#   'name': 'Panora AVM',
#   'category': ['Alışveriş', 'Yeme-İçme'],
#   'coordinates': {'lat': 39.851, 'lng': 32.8162},
#   'city': 'Ankara',
#   'district': 'Oran',
#   'average_stay_minutes': 150,
#   'average_spend': {'amount': 220, 'currency': 'TRY'},
#   'best_visit_times': {'season': ['Tüm yıl'],
#    'days': ['Cumartesi', 'Pazar'],
#    'hours': ['10:00-22:00']},
#   'tags': ['alışveriş', 'lüks', 'sinema'],
#   'popularity_score': 85,
#   'virality_trend': 'stabil',
#   'average_rating': 4.4,
#   'review_count': 11000,
#   'sources': ['Google Maps', 'Instagram'],
#   'photos': ['https://maps.googleapis.com/photo/panora',
#    'https://instagram.com/panora.jpg']},
#  {'id': 'ankara_26',
#   'name': 'Kentpark AVM',
#   'category': ['Alışveriş', 'Moda'],
#   'coordinates': {'lat': 39.9115, 'lng': 32.795},
#   'city': 'Ankara',
#   'district': 'Söğütözü',
#   'average_stay_minutes': 160,
#   'average_spend': {'amount': 250, 'currency': 'TRY'},
#   'best_visit_times': {'season': ['Tüm yıl'],
#    'days': ['Hafta sonu'],
#    'hours': ['10:00-22:00']},
#   'tags': ['alışveriş', 'moda', 'restoran'],
#   'popularity_score': 87,
#   'virality_trend': 'yükselişte',
#   'average_rating': 4.5,
#   'review_count': 17500,
#   'sources': ['Google Maps'],
#   'photos': ['https://maps.googleapis.com/photo/kentpark',
#    'https://instagram.com/kentpark.jpg']},
#  {'id': 'ankara_27',
#   'name': 'Ankara Üniversitesi Botanik Bahçesi',
#   'category': ['Doğa', 'Bilim'],
#   'coordinates': {'lat': 39.937, 'lng': 32.8672},
#   'city': 'Ankara',
#   'district': 'Tandoğan',
#   'average_stay_minutes': 120,
#   'average_spend': {'amount': 0, 'currency': 'TRY'},
#   'best_visit_times': {'season': ['İlkbahar', 'Yaz'],
#    'days': ['Salı', 'Çarşamba'],
#    'hours': ['09:00-17:00']},
#   'tags': ['botanik', 'araştırma', 'doğa'],
#   'popularity_score': 74,
#   'virality_trend': 'stabil',
#   'average_rating': 4.2,
#   'review_count': 2100,
#   'sources': ['Google Maps'],
#   'photos': ['https://maps.googleapis.com/photo/unibotanik',
#    'https://instagram.com/unibotanik.jpg']},
#  {'id': 'ankara_28',
#   'name': 'ODTÜ Ormanı',
#   'category': ['Doğa', 'Yürüyüş'],
#   'coordinates': {'lat': 39.8905, 'lng': 32.78},
#   'city': 'Ankara',
#   'district': 'Çankaya',
#   'average_stay_minutes': 180,
#   'average_spend': {'amount': 10, 'currency': 'TRY'},
#   'best_visit_times': {'season': ['İlkbahar', 'Sonbahar'],
#    'days': ['Cumartesi', 'Pazar'],
#    'hours': ['07:00-20:00']},
#   'tags': ['doğa', 'spor', 'orman'],
#   'popularity_score': 83,
#   'virality_trend': 'stabil',
#   'average_rating': 4.6,
#   'review_count': 6800,
#   'sources': ['Google Maps'],
#   'photos': ['https://maps.googleapis.com/photo/odtu',
#    'https://instagram.com/odtu.jpg']},
#  {'id': 'ankara_29',
#   'name': 'Dikmen Vadisi',
#   'category': ['Doğa', 'Park'],
#   'coordinates': {'lat': 39.8791, 'lng': 32.8523},
#   'city': 'Ankara',
#   'district': 'Çankaya',
#   'average_stay_minutes': 120,
#   'average_spend': {'amount': 20, 'currency': 'TRY'},
#   'best_visit_times': {'season': ['İlkbahar', 'Yaz'],
#    'days': ['Hafta sonu'],
#    'hours': ['08:00-22:00']},
#   'tags': ['doğa', 'vadiler', 'park'],
#   'popularity_score': 81,
#   'virality_trend': 'yükselişte',
#   'average_rating': 4.4,
#   'review_count': 8900,
#   'sources': ['Google Maps'],
#   'photos': ['https://maps.googleapis.com/photo/dikmen',
#    'https://instagram.com/dikmen.jpg']},
#  {'id': 'ankara_30',
#   'name': 'Hacı Bayram Veli Camii',
#   'category': ['Dini', 'Tarihi'],
#   'coordinates': {'lat': 39.9441, 'lng': 32.8611},
#   'city': 'Ankara',
#   'district': 'Ulus',
#   'average_stay_minutes': 60,
#   'average_spend': {'amount': 0, 'currency': 'TRY'},
#   'best_visit_times': {'season': ['Tüm yıl'],
#    'days': ['Her gün'],
#    'hours': ['Gün boyu']},
#   'tags': ['ibadet', 'camii', 'tarihi'],
#   'popularity_score': 90,
#   'virality_trend': 'stabil',
#   'average_rating': 4.8,
#   'review_count': 21000,
#   'sources': ['Google Maps', 'Instagram'],
#   'photos': ['https://maps.googleapis.com/photo/hacibayram',
#    'https://instagram.com/hacibayram.jpg']},
#  {'id': 'ankara_31',
#   'name': 'Ankara Kalesi',
#   'category': ['Tarihi', 'Manzara'],
#   'coordinates': {'lat': 39.941, 'lng': 32.865},
#   'city': 'Ankara',
#   'district': 'Altındağ',
#   'average_stay_minutes': 90,
#   'average_spend': {'amount': 20, 'currency': 'TRY'},
#   'best_visit_times': {'season': ['İlkbahar', 'Sonbahar'],
#    'days': ['Her gün'],
#    'hours': ['09:00-18:00']},
#   'tags': ['tarihi', 'manzara', 'fotoğraf'],
#   'popularity_score': 92,
#   'virality_trend': 'yükselişte',
#   'average_rating': 4.7,
#   'review_count': 12500,
#   'sources': ['Google Maps', 'Instagram'],
#   'photos': ['https://maps.googleapis.com/photo/ankarakalesi',
#    'https://instagram.com/ankarakalesi.jpg']},
#  {'id': 'ankara_32',
#   'name': 'Etnografya Müzesi',
#   'category': ['Müze', 'Tarihi'],
#   'coordinates': {'lat': 39.9331, 'lng': 32.8597},
#   'city': 'Ankara',
#   'district': 'Altındağ',
#   'average_stay_minutes': 90,
#   'average_spend': {'amount': 50, 'currency': 'TRY'},
#   'best_visit_times': {'season': ['İlkbahar', 'Yaz'],
#    'days': ['Salı', 'Çarşamba', 'Perşembe'],
#    'hours': ['09:00-17:00']},
#   'tags': ['tarih', 'sanat', 'kültür'],
#   'popularity_score': 85,
#   'virality_trend': 'stabil',
#   'average_rating': 4.6,
#   'review_count': 7200,
#   'sources': ['Google Maps'],
#   'photos': ['https://maps.googleapis.com/photo/etnografya',
#    'https://instagram.com/etnografya.jpg']},
#  {'id': 'ankara_33',
#   'name': 'Göksu Parkı',
#   'category': ['Park', 'Doğa'],
#   'coordinates': {'lat': 39.9581, 'lng': 32.6583},
#   'city': 'Ankara',
#   'district': 'Eryaman',
#   'average_stay_minutes': 150,
#   'average_spend': {'amount': 30, 'currency': 'TRY'},
#   'best_visit_times': {'season': ['İlkbahar', 'Yaz', 'Sonbahar'],
#    'days': ['Cumartesi', 'Pazar'],
#    'hours': ['08:00-22:00']},
#   'tags': ['piknik', 'doğa', 'aile'],
#   'popularity_score': 84,
#   'virality_trend': 'yükselişte',
#   'average_rating': 4.5,
#   'review_count': 9800,
#   'sources': ['Google Maps'],
#   'photos': ['https://maps.googleapis.com/photo/goksu',
#    'https://instagram.com/goksu.jpg']},
#  {'id': 'ankara_34',
#   'name': 'Ahlatlıbel Tesisleri',
#   'category': ['Doğa', 'Spor'],
#   'coordinates': {'lat': 39.847, 'lng': 32.7999},
#   'city': 'Ankara',
#   'district': 'Çankaya',
#   'average_stay_minutes': 180,
#   'average_spend': {'amount': 60, 'currency': 'TRY'},
#   'best_visit_times': {'season': ['İlkbahar', 'Sonbahar'],
#    'days': ['Cumartesi', 'Pazar'],
#    'hours': ['08:00-21:00']},
#   'tags': ['spor', 'doğa', 'piknik'],
#   'popularity_score': 82,
#   'virality_trend': 'stabil',
#   'average_rating': 4.4,
#   'review_count': 6400,
#   'sources': ['Google Maps'],
#   'photos': ['https://maps.googleapis.com/photo/ahlatlibel',
#    'https://instagram.com/ahlatlibel.jpg']},
#  {'id': 'ankara_35',
#   'name': 'Çıkrıkçılar Yokuşu',
#   'category': ['Tarihi', 'Alışveriş'],
#   'coordinates': {'lat': 39.9432, 'lng': 32.8622},
#   'city': 'Ankara',
#   'district': 'Ulus',
#   'average_stay_minutes': 120,
#   'average_spend': {'amount': 100, 'currency': 'TRY'},
#   'best_visit_times': {'season': ['Tüm yıl'],
#    'days': ['Cumartesi', 'Pazar'],
#    'hours': ['09:00-20:00']},
#   'tags': ['antikacı', 'alışveriş', 'tarihi'],
#   'popularity_score': 78,
#   'virality_trend': 'yükselişte',
#   'average_rating': 4.3,
#   'review_count': 4300,
#   'sources': ['Google Maps', 'Instagram'],
#   'photos': ['https://maps.googleapis.com/photo/cikrikcilar',
#    'https://instagram.com/cikrikcilar.jpg']},
#  {'id': 'ankara_36',
#   'name': 'Ankara Sanat Tiyatrosu',
#   'category': ['Sanat', 'Tiyatro'],
#   'coordinates': {'lat': 39.9256, 'lng': 32.8501},
#   'city': 'Ankara',
#   'district': 'Kolej',
#   'average_stay_minutes': 120,
#   'average_spend': {'amount': 90, 'currency': 'TRY'},
#   'best_visit_times': {'season': ['Kış'],
#    'days': ['Cuma', 'Cumartesi'],
#    'hours': ['19:00-22:00']},
#   'tags': ['tiyatro', 'sanat', 'kültür'],
#   'popularity_score': 76,
#   'virality_trend': 'stabil',
#   'average_rating': 4.6,
#   'review_count': 3100,
#   'sources': ['Google Maps'],
#   'photos': ['https://maps.googleapis.com/photo/tiyatro',
#    'https://instagram.com/tiyatro.jpg']},
#  {'id': 'ankara_37',
#   'name': 'Cermodern Sinema',
#   'category': ['Sanat', 'Sinema'],
#   'coordinates': {'lat': 39.9336, 'lng': 32.8507},
#   'city': 'Ankara',
#   'district': 'Sıhhiye',
#   'average_stay_minutes': 150,
#   'average_spend': {'amount': 80, 'currency': 'TRY'},
#   'best_visit_times': {'season': ['Tüm yıl'],
#    'days': ['Cumartesi', 'Pazar'],
#    'hours': ['18:00-23:00']},
#   'tags': ['sinema', 'sanat', 'festival'],
#   'popularity_score': 79,
#   'virality_trend': 'stabil',
#   'average_rating': 4.5,
#   'review_count': 2700,
#   'sources': ['Google Maps'],
#   'photos': ['https://maps.googleapis.com/photo/cersinema',
#    'https://instagram.com/cersinema.jpg']},
#  {'id': 'ankara_38',
#   'name': 'Müze Evliyagil',
#   'category': ['Sanat', 'Müze'],
#   'coordinates': {'lat': 39.8421, 'lng': 32.8202},
#   'city': 'Ankara',
#   'district': 'Çankaya',
#   'average_stay_minutes': 90,
#   'average_spend': {'amount': 50, 'currency': 'TRY'},
#   'best_visit_times': {'season': ['İlkbahar', 'Sonbahar'],
#    'days': ['Cumartesi', 'Pazar'],
#    'hours': ['10:00-18:00']},
#   'tags': ['sanat', 'galeri', 'müze'],
#   'popularity_score': 75,
#   'virality_trend': 'yükselişte',
#   'average_rating': 4.4,
#   'review_count': 2100,
#   'sources': ['Google Maps', 'Instagram'],
#   'photos': ['https://maps.googleapis.com/photo/evliyagil',
#    'https://instagram.com/evliyagil.jpg']},
#  {'id': 'ankara_39',
#   'name': 'Ankara Resim ve Heykel Müzesi',
#   'category': ['Sanat', 'Müze'],
#   'coordinates': {'lat': 39.9335, 'lng': 32.8595},
#   'city': 'Ankara',
#   'district': 'Altındağ',
#   'average_stay_minutes': 100,
#   'average_spend': {'amount': 40, 'currency': 'TRY'},
#   'best_visit_times': {'season': ['İlkbahar', 'Kış'],
#    'days': ['Çarşamba', 'Perşembe'],
#    'hours': ['09:00-17:00']},
#   'tags': ['sanat', 'resim', 'tarih'],
#   'popularity_score': 80,
#   'virality_trend': 'stabil',
#   'average_rating': 4.5,
#   'review_count': 5000,
#   'sources': ['Google Maps'],
#   'photos': ['https://maps.googleapis.com/photo/heykel',
#    'https://instagram.com/heykel.jpg']},
#  {'id': 'ankara_40',
#   'name': 'Çıngırlı Höyük',
#   'category': ['Arkeoloji', 'Tarihi'],
#   'coordinates': {'lat': 40.159, 'lng': 33.085},
#   'city': 'Ankara',
#   'district': 'Polatlı',
#   'average_stay_minutes': 60,
#   'average_spend': {'amount': 0, 'currency': 'TRY'},
#   'best_visit_times': {'season': ['İlkbahar', 'Yaz'],
#    'days': ['Hafta içi'],
#    'hours': ['09:00-17:00']},
#   'tags': ['arkeoloji', 'höyük', 'tarih'],
#   'popularity_score': 68,
#   'virality_trend': 'stabil',
#   'average_rating': 4.1,
#   'review_count': 600,
#   'sources': ['Google Maps'],
#   'photos': ['https://maps.googleapis.com/photo/cingirli',
#    'https://instagram.com/cingirli.jpg']},
#  {'id': 'ankara_41',
#   'name': 'Polatlı Sakarya Meydan Muharebesi Tarihi Milli Parkı',
#   'category': ['Tarihi', 'Milli Park'],
#   'coordinates': {'lat': 39.5842, 'lng': 32.1471},
#   'city': 'Ankara',
#   'district': 'Polatlı',
#   'average_stay_minutes': 120,
#   'average_spend': {'amount': 30, 'currency': 'TRY'},
#   'best_visit_times': {'season': ['İlkbahar', 'Sonbahar'],
#    'days': ['Cumartesi', 'Pazar'],
#    'hours': ['09:00-18:00']},
#   'tags': ['tarih', 'savaş', 'park'],
#   'popularity_score': 82,
#   'virality_trend': 'yükselişte',
#   'average_rating': 4.7,
#   'review_count': 4800,
#   'sources': ['Google Maps', 'Instagram'],
#   'photos': ['https://maps.googleapis.com/photo/sakaryaparki',
#    'https://instagram.com/sakarya.jpg']},
#  {'id': 'ankara_42',
#   'name': 'Nallıhan Kuş Cenneti',
#   'category': ['Doğa', 'Gözlem'],
#   'coordinates': {'lat': 40.1845, 'lng': 31.3456},
#   'city': 'Ankara',
#   'district': 'Nallıhan',
#   'average_stay_minutes': 180,
#   'average_spend': {'amount': 20, 'currency': 'TRY'},
#   'best_visit_times': {'season': ['İlkbahar', 'Sonbahar'],
#    'days': ['Cumartesi', 'Pazar'],
#    'hours': ['07:00-19:00']},
#   'tags': ['kuş', 'doğa', 'fotoğraf'],
#   'popularity_score': 87,
#   'virality_trend': 'yükselişte',
#   'average_rating': 4.8,
#   'review_count': 7400,
#   'sources': ['Google Maps', 'Instagram'],
#   'photos': ['https://maps.googleapis.com/photo/nallihan',
#    'https://instagram.com/nallihan.jpg']},
#  {'id': 'ankara_43',
#   'name': 'Ayaş Kaplıcaları',
#   'category': ['Sağlık', 'Kaplıca'],
#   'coordinates': {'lat': 40.018, 'lng': 32.34},
#   'city': 'Ankara',
#   'district': 'Ayaş',
#   'average_stay_minutes': 150,
#   'average_spend': {'amount': 120, 'currency': 'TRY'},
#   'best_visit_times': {'season': ['Kış', 'İlkbahar'],
#    'days': ['Cumartesi', 'Pazar'],
#    'hours': ['09:00-22:00']},
#   'tags': ['kaplıca', 'sağlık', 'dinlenme'],
#   'popularity_score': 81,
#   'virality_trend': 'stabil',
#   'average_rating': 4.4,
#   'review_count': 3200,
#   'sources': ['Google Maps'],
#   'photos': ['https://maps.googleapis.com/photo/ayas',
#    'https://instagram.com/ayas.jpg']},
#  {'id': 'ankara_44',
#   'name': 'Kızılcahamam Soğuksu Milli Parkı',
#   'category': ['Doğa', 'Milli Park'],
#   'coordinates': {'lat': 40.4692, 'lng': 32.645},
#   'city': 'Ankara',
#   'district': 'Kızılcahamam',
#   'average_stay_minutes': 240,
#   'average_spend': {'amount': 50, 'currency': 'TRY'},
#   'best_visit_times': {'season': ['İlkbahar', 'Yaz', 'Sonbahar'],
#    'days': ['Cumartesi', 'Pazar'],
#    'hours': ['08:00-20:00']},
#   'tags': ['doğa', 'milli park', 'piknik'],
#   'popularity_score': 89,
#   'virality_trend': 'yükselişte',
#   'average_rating': 4.8,
#   'review_count': 11200,
#   'sources': ['Google Maps'],
#   'photos': ['https://maps.googleapis.com/photo/soguksu',
#    'https://instagram.com/soguksu.jpg']},
#  {'id': 'ankara_45',
#   'name': 'Elmadağ Kayak Merkezi',
#   'category': ['Spor', 'Kış'],
#   'coordinates': {'lat': 39.92, 'lng': 33.23},
#   'city': 'Ankara',
#   'district': 'Elmadağ',
#   'average_stay_minutes': 300,
#   'average_spend': {'amount': 250, 'currency': 'TRY'},
#   'best_visit_times': {'season': ['Kış'],
#    'days': ['Cumartesi', 'Pazar'],
#    'hours': ['09:00-17:00']},
#   'tags': ['kayak', 'spor', 'kış'],
#   'popularity_score': 83,
#   'virality_trend': 'yükselişte',
#   'average_rating': 4.5,
#   'review_count': 5200,
#   'sources': ['Google Maps', 'Instagram'],
#   'photos': ['https://maps.googleapis.com/photo/elmadağ',
#    'https://instagram.com/elmadağ.jpg']},
#  {'id': 'ankara_46',
#   'name': 'Şereflikoçhisar Tuz Gölü',
#   'category': ['Doğa', 'Göl'],
#   'coordinates': {'lat': 38.75, 'lng': 33.3333},
#   'city': 'Ankara',
#   'district': 'Şereflikoçhisar',
#   'average_stay_minutes': 150,
#   'average_spend': {'amount': 10, 'currency': 'TRY'},
#   'best_visit_times': {'season': ['Yaz', 'Sonbahar'],
#    'days': ['Her gün'],
#    'hours': ['08:00-21:00']},
#   'tags': ['doğa', 'fotoğraf', 'göl'],
#   'popularity_score': 90,
#   'virality_trend': 'yükselişte',
#   'average_rating': 4.7,
#   'review_count': 15800,
#   'sources': ['Google Maps', 'Instagram'],
#   'photos': ['https://maps.googleapis.com/photo/tuzgolu',
#    'https://instagram.com/tuzgolu.jpg']},
#  {'id': 'ankara_47',
#   'name': 'Güdül İnönü Mağaraları',
#   'category': ['Tarihi', 'Doğa'],
#   'coordinates': {'lat': 40.21, 'lng': 32.24},
#   'city': 'Ankara',
#   'district': 'Güdül',
#   'average_stay_minutes': 90,
#   'average_spend': {'amount': 0, 'currency': 'TRY'},
#   'best_visit_times': {'season': ['İlkbahar', 'Sonbahar'],
#    'days': ['Cumartesi', 'Pazar'],
#    'hours': ['09:00-18:00']},
#   'tags': ['tarih', 'mağara', 'doğa'],
#   'popularity_score': 77,
#   'virality_trend': 'stabil',
#   'average_rating': 4.3,
#   'review_count': 1900,
#   'sources': ['Google Maps'],
#   'photos': ['https://maps.googleapis.com/photo/gudul',
#    'https://instagram.com/gudul.jpg']},
#  {'id': 'ankara_48',
#   'name': 'Kalecik Bağları',
#   'category': ['Doğa', 'Yeme-İçme'],
#   'coordinates': {'lat': 40.097, 'lng': 33.41},
#   'city': 'Ankara',
#   'district': 'Kalecik',
#   'average_stay_minutes': 180,
#   'average_spend': {'amount': 200, 'currency': 'TRY'},
#   'best_visit_times': {'season': ['Sonbahar'],
#    'days': ['Cumartesi', 'Pazar'],
#    'hours': ['10:00-19:00']},
#   'tags': ['üzüm', 'şarap', 'doğa'],
#   'popularity_score': 84,
#   'virality_trend': 'yükselişte',
#   'average_rating': 4.6,
#   'review_count': 3100,
#   'sources': ['Google Maps', 'Instagram'],
#   'photos': ['https://maps.googleapis.com/photo/kalecik',
#    'https://instagram.com/kalecik.jpg']},
#  {'id': 'ankara_49',
#   'name': 'Ayaş Güvercinlik Vadisi',
#   'category': ['Doğa', 'Yürüyüş'],
#   'coordinates': {'lat': 40.1, 'lng': 32.31},
#   'city': 'Ankara',
#   'district': 'Ayaş',
#   'average_stay_minutes': 120,
#   'average_spend': {'amount': 20, 'currency': 'TRY'},
#   'best_visit_times': {'season': ['İlkbahar', 'Sonbahar'],
#    'days': ['Cumartesi', 'Pazar'],
#    'hours': ['08:00-20:00']},
#   'tags': ['doğa', 'vadiler', 'yürüyüş'],
#   'popularity_score': 80,
#   'virality_trend': 'stabil',
#   'average_rating': 4.4,
#   'review_count': 2200,
#   'sources': ['Google Maps'],
#   'photos': ['https://maps.googleapis.com/photo/guvercinlik',
#    'https://instagram.com/guvercinlik.jpg']},
#  {'id': 'ankara_50',
#   'name': 'Ayaş Çayı',
#   'category': ['Doğa', 'Piknik'],
#   'coordinates': {'lat': 40.015, 'lng': 32.28},
#   'city': 'Ankara',
#   'district': 'Ayaş',
#   'average_stay_minutes': 150,
#   'average_spend': {'amount': 10, 'currency': 'TRY'},
#   'best_visit_times': {'season': ['İlkbahar', 'Yaz'],
#    'days': ['Her gün'],
#    'hours': ['08:00-21:00']},
#   'tags': ['piknik', 'su kenarı', 'doğa'],
#   'popularity_score': 73,
#   'virality_trend': 'stabil',
#   'average_rating': 4.2,
#   'review_count': 1200,
#   'sources': ['Google Maps'],
#   'photos': ['https://maps.googleapis.com/photo/ayasçay',
#    'https://instagram.com/ayasçay.jpg']},
#  {'id': 'ankara_51',
#   'name': 'Çubuk Karagöl Tabiat Parkı',
#   'category': ['Doğa', 'Milli Park'],
#   'coordinates': {'lat': 40.49, 'lng': 32.78},
#   'city': 'Ankara',
#   'district': 'Çubuk',
#   'average_stay_minutes': 240,
#   'average_spend': {'amount': 30, 'currency': 'TRY'},
#   'best_visit_times': {'season': ['İlkbahar', 'Yaz', 'Sonbahar'],
#    'days': ['Cumartesi', 'Pazar'],
#    'hours': ['08:00-20:00']},
#   'tags': ['doğa', 'kamp', 'piknik'],
#   'popularity_score': 91,
#   'virality_trend': 'yükselişte',
# ...
#   'photos': ['https://en.wikipedia.org/wiki/Anamur_Sugar_Museum_(local)']},
#  {'id': 'mersin_75',
#   'name': 'Mersin Contemporary Art Gallery (local)',
#   'category': ['Turistik', 'Doğa'],
#   'coordinates': {'lat': 36.805, 'lng': 34.64},
#   'city': 'Mersin',
#   'district': 'Yenişehir',
#   'average_stay_minutes': 60,
#   'average_spend': {'amount': 60, 'currency': 'TRY'},
#   'best_visit_times': {'season': ['Yaz', 'Kış'],
#    'days': ['Her gün'],
#    'hours': ['08:00-19:00']},
#   'tags': ['fotoğraf', 'güneşlenme', 'kamp'],
#   'popularity_score': 97,
#   'virality_trend': 'orta',
#   'average_rating': 4.0,
#   'review_count': 7220,
#   'sources': ['Wikipedia', 'TripAdvisor'],
#   'photos': ['https://en.wikipedia.org/wiki/Mersin_Contemporary_Art_Gallery_(local)']},
#  {'id': 'mersin_76',
#   'name': 'Kızıltepe (local hill)',
#   'category': ['Turistik', 'Doğa'],
#   'coordinates': {'lat': 36.3, 'lng': 33.45},
#   'city': 'Mersin',
#   'district': 'Gülnar',
#   'average_stay_minutes': 30,
#   'average_spend': {'amount': 80, 'currency': 'TRY'},
#   'best_visit_times': {'season': ['Kış', 'Yaz'],
#    'days': ['Her gün'],
#    'hours': ['08:00-18:00']},
#   'tags': ['tarih', 'doğa', 'plaj'],
#   'popularity_score': 89,
#   'virality_trend': 'yükselişte',
#   'average_rating': 4.6,
#   'review_count': 2946,
#   'sources': ['Wikipedia'],
#   'photos': ['https://en.wikipedia.org/wiki/Kızıltepe_(local_hill)']},
#  {'id': 'mersin_77',
#   'name': 'Belen Pass viewpoint',
#   'category': ['Turistik', 'Doğa'],
#   'coordinates': {'lat': 37.05, 'lng': 34.1},
#   'city': 'Mersin',
#   'district': 'Toroslar',
#   'average_stay_minutes': 30,
#   'average_spend': {'amount': 150, 'currency': 'TRY'},
#   'best_visit_times': {'season': ['Kış', 'Yaz'],
#    'days': ['Her gün'],
#    'hours': ['09:00-16:00']},
#   'tags': ['manzara', 'doğa', 'dalış'],
#   'popularity_score': 94,
#   'virality_trend': 'istikrarlı',
#   'average_rating': 4.7,
#   'review_count': 427,
#   'sources': ['Wikipedia', 'TripAdvisor'],
#   'photos': ['https://en.wikipedia.org/wiki/Belen_Pass_viewpoint']},
#  {'id': 'mersin_78',
#   'name': 'Kocaköy (village)',
#   'category': ['Turistik', 'Doğa'],
#   'coordinates': {'lat': 37.12, 'lng': 33.7},
#   'city': 'Mersin',
#   'district': 'Mut',
#   'average_stay_minutes': 60,
#   'average_spend': {'amount': 60, 'currency': 'TRY'},
#   'best_visit_times': {'season': ['Kış', 'İlkbahar'],
#    'days': ['Her gün'],
#    'hours': ['10:00-20:00']},
#   'tags': ['güneşlenme', 'şehir simgesi', 'manzara'],
#   'popularity_score': 79,
#   'virality_trend': 'istikrarlı',
#   'average_rating': 4.6,
#   'review_count': 4169,
#   'sources': ['Wikipedia', 'TripAdvisor'],
#   'photos': ['https://en.wikipedia.org/wiki/Kocaköy_(village)']},
#  {'id': 'mersin_79',
#   'name': 'Suluk Cave (approx)',
#   'category': ['Mağara', 'Doğa'],
#   'coordinates': {'lat': 36.5, 'lng': 34.33},
#   'city': 'Mersin',
#   'district': 'Erdemli',
#   'average_stay_minutes': 75,
#   'average_spend': {'amount': 60, 'currency': 'TRY'},
#   'best_visit_times': {'season': ['Yaz', 'Sonbahar'],
#    'days': ['Her gün'],
#    'hours': ['10:00-20:00']},
#   'tags': ['arkeoloji', 'dalış', 'şehir simgesi'],
#   'popularity_score': 96,
#   'virality_trend': 'yüksek',
#   'average_rating': 4.6,
#   'review_count': 5954,
#   'sources': ['Wikipedia', 'TripAdvisor'],
#   'photos': ['https://en.wikipedia.org/wiki/Suluk_Cave_(approx)']},
#  {'id': 'mersin_80',
#   'name': 'Turan Market (local)',
#   'category': ['Turistik', 'Doğa'],
#   'coordinates': {'lat': 36.798, 'lng': 34.631},
#   'city': 'Mersin',
#   'district': 'Mersin',
#   'average_stay_minutes': 150,
#   'average_spend': {'amount': 150, 'currency': 'TRY'},
#   'best_visit_times': {'season': ['Sonbahar', 'Yaz'],
#    'days': ['Her gün'],
#    'hours': ['08:00-16:00']},
#   'tags': ['tarih', 'dalış', 'fotoğraf'],
#   'popularity_score': 82,
#   'virality_trend': 'istikrarlı',
#   'average_rating': 4.2,
#   'review_count': 2493,
#   'sources': ['Wikipedia', 'TripAdvisor'],
#   'photos': ['https://en.wikipedia.org/wiki/Turan_Market_(local)']},
#  {'id': 'mersin_81',
#   'name': 'Seaport promenade (Mezitli)',
#   'category': ['Sahil', 'Doğa'],
#   'coordinates': {'lat': 36.77, 'lng': 34.6},
#   'city': 'Mersin',
#   'district': 'Mezitli',
#   'average_stay_minutes': 30,
#   'average_spend': {'amount': 20, 'currency': 'TRY'},
#   'best_visit_times': {'season': ['Kış', 'Sonbahar'],
#    'days': ['Her gün'],
#    'hours': ['09:00-18:00']},
#   'tags': ['yürüyüş', 'kamp', 'manzara'],
#   'popularity_score': 82,
#   'virality_trend': 'yüksek',
#   'average_rating': 4.2,
#   'review_count': 4558,
#   'sources': ['Wikipedia'],
#   'photos': ['https://en.wikipedia.org/wiki/Seaport_promenade_(Mezitli)']},
#  {'id': 'mersin_82',
#   'name': 'Marina Events Ground',
#   'category': ['Sahil', 'Doğa'],
#   'coordinates': {'lat': 36.798, 'lng': 34.632},
#   'city': 'Mersin',
#   'district': 'Akdeniz',
#   'average_stay_minutes': 90,
#   'average_spend': {'amount': 0, 'currency': 'TRY'},
#   'best_visit_times': {'season': ['Kış', 'Yaz'],
#    'days': ['Her gün'],
#    'hours': ['09:00-19:00']},
#   'tags': ['arkeoloji', 'doğa', 'şehir simgesi'],
#   'popularity_score': 82,
#   'virality_trend': 'yükselişte',
#   'average_rating': 3.9,
#   'review_count': 6472,
#   'sources': ['Wikipedia', 'TripAdvisor'],
#   'photos': ['https://en.wikipedia.org/wiki/Marina_Events_Ground']},
#  {'id': 'mersin_83',
#   'name': 'Köprüçay excursion area',
#   'category': ['Turistik', 'Doğa'],
#   'coordinates': {'lat': 36.92, 'lng': 34.9},
#   'city': 'Mersin',
#   'district': 'Tarsus',
#   'average_stay_minutes': 120,
#   'average_spend': {'amount': 50, 'currency': 'TRY'},
#   'best_visit_times': {'season': ['Yaz', 'Kış'],
#    'days': ['Her gün'],
#    'hours': ['10:00-16:00']},
#   'tags': ['şehir simgesi', 'kamp', 'doğa'],
#   'popularity_score': 95,
#   'virality_trend': 'yüksek',
#   'average_rating': 3.8,
#   'review_count': 1555,
#   'sources': ['Wikipedia', 'TripAdvisor'],
#   'photos': ['https://en.wikipedia.org/wiki/Köprüçay_excursion_area']},
#  {'id': 'mersin_84',
#   'name': 'Eshab-ı Kehf (Tarsus cave)',
#   'category': ['Mağara', 'Doğa'],
#   'coordinates': {'lat': 36.918, 'lng': 34.89},
#   'city': 'Mersin',
#   'district': 'Tarsus',
#   'average_stay_minutes': 120,
#   'average_spend': {'amount': 40, 'currency': 'TRY'},
#   'best_visit_times': {'season': ['Sonbahar', 'İlkbahar'],
#    'days': ['Her gün'],
#    'hours': ['09:00-18:00']},
#   'tags': ['doğa', 'plaj', 'dalış'],
#   'popularity_score': 70,
#   'virality_trend': 'orta',
#   'average_rating': 4.5,
#   'review_count': 968,
#   'sources': ['Wikipedia'],
#   'photos': ['https://en.wikipedia.org/wiki/Eshab-ı_Kehf_(Tarsus_cave)']},
#  {'id': 'mersin_85',
#   'name': "Tarsus Cleopatra's Gate area",
#   'category': ['Turistik', 'Doğa'],
#   'coordinates': {'lat': 36.916, 'lng': 34.898},
#   'city': 'Mersin',
#   'district': 'Tarsus',
#   'average_stay_minutes': 60,
#   'average_spend': {'amount': 150, 'currency': 'TRY'},
#   'best_visit_times': {'season': ['İlkbahar', 'Kış'],
#    'days': ['Her gün'],
#    'hours': ['09:00-19:00']},
#   'tags': ['kamp', 'fotoğraf', 'aile dostu'],
#   'popularity_score': 76,
#   'virality_trend': 'istikrarlı',
#   'average_rating': 4.6,
#   'review_count': 991,
#   'sources': ['Wikipedia', 'TripAdvisor'],
#   'photos': ["https://en.wikipedia.org/wiki/Tarsus_Cleopatra's_Gate_area"]},
#  {'id': 'mersin_86',
#   'name': 'Local Fishing Pier (Anamur)',
#   'category': ['Turistik', 'Doğa'],
#   'coordinates': {'lat': 36.073, 'lng': 34.597},
#   'city': 'Mersin',
#   'district': 'Anamur',
#   'average_stay_minutes': 45,
#   'average_spend': {'amount': 30, 'currency': 'TRY'},
#   'best_visit_times': {'season': ['İlkbahar', 'Sonbahar'],
#    'days': ['Her gün'],
#    'hours': ['10:00-16:00']},
#   'tags': ['arkeoloji', 'tarih', 'kamp'],
#   'popularity_score': 90,
#   'virality_trend': 'istikrarlı',
#   'average_rating': 3.9,
#   'review_count': 887,
#   'sources': ['Wikipedia', 'TripAdvisor'],
#   'photos': ['https://en.wikipedia.org/wiki/Local_Fishing_Pier_(Anamur)']},
#  {'id': 'mersin_87',
#   'name': 'Boat Tour Start (Taşucu)',
#   'category': ['Turistik', 'Doğa'],
#   'coordinates': {'lat': 36.33, 'lng': 33.96},
#   'city': 'Mersin',
#   'district': 'Silifke',
#   'average_stay_minutes': 60,
#   'average_spend': {'amount': 60, 'currency': 'TRY'},
#   'best_visit_times': {'season': ['Yaz', 'İlkbahar'],
#    'days': ['Her gün'],
#    'hours': ['10:00-19:00']},
#   'tags': ['arkeoloji', 'kamp', 'dalış'],
#   'popularity_score': 88,
#   'virality_trend': 'yükselişte',
#   'average_rating': 4.2,
#   'review_count': 3954,
#   'sources': ['Wikipedia'],
#   'photos': ['https://en.wikipedia.org/wiki/Boat_Tour_Start_(Taşucu)']},
#  {'id': 'mersin_88',
#   'name': 'Silifke Harbor Walk',
#   'category': ['Turistik', 'Doğa'],
#   'coordinates': {'lat': 36.33, 'lng': 33.96},
#   'city': 'Mersin',
#   'district': 'Silifke',
#   'average_stay_minutes': 75,
#   'average_spend': {'amount': 100, 'currency': 'TRY'},
#   'best_visit_times': {'season': ['Kış', 'Yaz'],
#    'days': ['Her gün'],
#    'hours': ['09:00-18:00']},
#   'tags': ['plaj', 'tarih', 'aile dostu'],
#   'popularity_score': 74,
#   'virality_trend': 'orta',
#   'average_rating': 4.8,
#   'review_count': 697,
#   'sources': ['Wikipedia', 'TripAdvisor'],
#   'photos': ['https://en.wikipedia.org/wiki/Silifke_Harbor_Walk']},
#  {'id': 'mersin_89',
#   'name': 'Local Beach 90',
#   'category': ['Sahil', 'Doğa'],
#   'coordinates': {'lat': 36.519329, 'lng': 34.262372},
#   'city': 'Mersin',
#   'district': 'Erdemli',
#   'average_stay_minutes': 120,
#   'average_spend': {'amount': 100, 'currency': 'TRY'},
#   'best_visit_times': {'season': ['Yaz', 'İlkbahar'],
#    'days': ['Her gün'],
#    'hours': ['10:00-20:00']},
#   'tags': ['doğa', 'tarih', 'fotoğraf'],
#   'popularity_score': 71,
#   'virality_trend': 'istikrarlı',
#   'average_rating': 4.6,
#   'review_count': 2884,
#   'sources': ['Wikipedia'],
#   'photos': ['https://en.wikipedia.org/wiki/Local_Beach_90']},
#  {'id': 'mersin_90',
#   'name': 'Local Ruins 91',
#   'category': ['Antik', 'Tarih'],
#   'coordinates': {'lat': 36.085687, 'lng': 34.583256},
#   'city': 'Mersin',
#   'district': 'Anamur',
#   'average_stay_minutes': 120,
#   'average_spend': {'amount': 100, 'currency': 'TRY'},
#   'best_visit_times': {'season': ['Yaz', 'Sonbahar'],
#    'days': ['Her gün'],
#    'hours': ['10:00-17:00']},
#   'tags': ['manzara', 'fotoğraf', 'arkeoloji'],
#   'popularity_score': 80,
#   'virality_trend': 'yükselişte',
#   'average_rating': 3.9,
#   'review_count': 7801,
#   'sources': ['Wikipedia'],
#   'photos': ['https://en.wikipedia.org/wiki/Local_Ruins_91']},
#  {'id': 'mersin_91',
#   'name': 'Local Picnic Area 92',
#   'category': ['Turistik', 'Doğa'],
#   'coordinates': {'lat': 37.192542, 'lng': 33.694818},
#   'city': 'Mersin',
#   'district': 'Mut',
#   'average_stay_minutes': 60,
#   'average_spend': {'amount': 100, 'currency': 'TRY'},
#   'best_visit_times': {'season': ['Sonbahar', 'Yaz'],
#    'days': ['Her gün'],
#    'hours': ['10:00-17:00']},
#   'tags': ['plaj', 'kamp', 'şehir simgesi'],
#   'popularity_score': 90,
#   'virality_trend': 'yüksek',
#   'average_rating': 3.9,
#   'review_count': 4774,
#   'sources': ['Wikipedia'],
#   'photos': ['https://en.wikipedia.org/wiki/Local_Picnic_Area_92']},
#  {'id': 'mersin_92',
#   'name': 'Scenic Viewpoint 93',
#   'category': ['Turistik', 'Doğa'],
#   'coordinates': {'lat': 37.041031, 'lng': 34.90415},
#   'city': 'Mersin',
#   'district': 'Toroslar',
#   'average_stay_minutes': 120,
#   'average_spend': {'amount': 30, 'currency': 'TRY'},
#   'best_visit_times': {'season': ['Sonbahar', 'Yaz'],
#    'days': ['Her gün'],
#    'hours': ['08:00-18:00']},
#   'tags': ['tarih', 'plaj', 'şehir simgesi'],
#   'popularity_score': 77,
#   'virality_trend': 'istikrarlı',
#   'average_rating': 4.7,
#   'review_count': 7645,
#   'sources': ['Wikipedia', 'TripAdvisor'],
#   'photos': ['https://en.wikipedia.org/wiki/Scenic_Viewpoint_93']},
#  {'id': 'mersin_93',
#   'name': 'Small Harbor 94',
#   'category': ['Turistik', 'Doğa'],
#   'coordinates': {'lat': 36.330454, 'lng': 33.941993},
#   'city': 'Mersin',
#   'district': 'Silifke',
#   'average_stay_minutes': 90,
#   'average_spend': {'amount': 30, 'currency': 'TRY'},
#   'best_visit_times': {'season': ['Kış', 'Sonbahar'],
#    'days': ['Her gün'],
#    'hours': ['08:00-17:00']},
#   'tags': ['aile dostu', 'plaj', 'tarih'],
#   'popularity_score': 70,
#   'virality_trend': 'çok yüksek',
#   'average_rating': 3.8,
#   'review_count': 2300,
#   'sources': ['Wikipedia', 'TripAdvisor'],
#   'photos': ['https://en.wikipedia.org/wiki/Small_Harbor_94']},
#  {'id': 'mersin_94',
#   'name': 'Village Museum 95',
#   'category': ['Müze', 'Tarih'],
#   'coordinates': {'lat': 36.359344, 'lng': 33.476423},
#   'city': 'Mersin',
#   'district': 'Gülnar',
#   'average_stay_minutes': 120,
#   'average_spend': {'amount': 60, 'currency': 'TRY'},
#   'best_visit_times': {'season': ['İlkbahar', 'Sonbahar'],
#    'days': ['Her gün'],
#    'hours': ['09:00-17:00']},
#   'tags': ['yürüyüş', 'doğa', 'tarih'],
#   'popularity_score': 79,
#   'virality_trend': 'yükselişte',
#   'average_rating': 4.4,
#   'review_count': 3862,
#   'sources': ['Wikipedia', 'TripAdvisor'],
#   'photos': ['https://en.wikipedia.org/wiki/Village_Museum_95']},
#  {'id': 'mersin_95',
#   'name': 'Historic House 96',
#   'category': ['Turistik', 'Doğa'],
#   'coordinates': {'lat': 36.905452, 'lng': 34.916687},
#   'city': 'Mersin',
#   'district': 'Tarsus',
#   'average_stay_minutes': 90,
#   'average_spend': {'amount': 0, 'currency': 'TRY'},
#   'best_visit_times': {'season': ['Sonbahar', 'Kış'],
#    'days': ['Her gün'],
#    'hours': ['09:00-20:00']},
#   'tags': ['fotoğraf', 'doğa', 'güneşlenme'],
#   'popularity_score': 86,
#   'virality_trend': 'yükselişte',
#   'average_rating': 4.4,
#   'review_count': 7886,
#   'sources': ['Wikipedia'],
#   'photos': ['https://en.wikipedia.org/wiki/Historic_House_96']},
#  {'id': 'mersin_96',
#   'name': 'Coastal Walk 97',
#   'category': ['Turistik', 'Doğa'],
#   'coordinates': {'lat': 36.783881, 'lng': 34.599816},
#   'city': 'Mersin',
#   'district': 'Mezitli',
#   'average_stay_minutes': 45,
#   'average_spend': {'amount': 30, 'currency': 'TRY'},
#   'best_visit_times': {'season': ['Kış', 'Sonbahar'],
#    'days': ['Her gün'],
#    'hours': ['09:00-17:00']},
#   'tags': ['dalış', 'şehir simgesi', 'arkeoloji'],
#   'popularity_score': 95,
#   'virality_trend': 'yüksek',
#   'average_rating': 4.7,
#   'review_count': 4818,
#   'sources': ['Wikipedia', 'TripAdvisor'],
#   'photos': ['https://en.wikipedia.org/wiki/Coastal_Walk_97']},
#  {'id': 'mersin_97',
#   'name': 'Seaside Park 98',
#   'category': ['Turistik', 'Doğa'],
#   'coordinates': {'lat': 36.802886, 'lng': 34.64415},
#   'city': 'Mersin',
#   'district': 'Yenişehir',
#   'average_stay_minutes': 120,
#   'average_spend': {'amount': 20, 'currency': 'TRY'},
#   'best_visit_times': {'season': ['İlkbahar', 'Sonbahar'],
#    'days': ['Her gün'],
#    'hours': ['10:00-18:00']},
#   'tags': ['arkeoloji', 'aile dostu', 'yürüyüş'],
#   'popularity_score': 75,
#   'virality_trend': 'orta',
#   'average_rating': 3.9,
#   'review_count': 7649,
#   'sources': ['Wikipedia', 'TripAdvisor'],
#   'photos': ['https://en.wikipedia.org/wiki/Seaside_Park_98']},
#  {'id': 'mersin_98',
#   'name': 'Nature Trail 99',
#   'category': ['Turistik', 'Doğa'],
#   'coordinates': {'lat': 37.062977, 'lng': 34.9369},
#   'city': 'Mersin',
#   'district': 'Çamlıyayla',
#   'average_stay_minutes': 150,
#   'average_spend': {'amount': 80, 'currency': 'TRY'},
#   'best_visit_times': {'season': ['Yaz', 'Sonbahar'],
#    'days': ['Her gün'],
#    'hours': ['09:00-19:00']},
#   'tags': ['güneşlenme', 'dalış', 'tarih'],
#   'popularity_score': 80,
#   'virality_trend': 'yükselişte',
#   'average_rating': 4.4,
#   'review_count': 3593,
#   'sources': ['Wikipedia', 'TripAdvisor'],
#   'photos': ['https://en.wikipedia.org/wiki/Nature_Trail_99']},
#  {'id': 'mersin_99',
#   'name': 'Local Beach 100',
#   'category': ['Sahil', 'Doğa'],
#   'coordinates': {'lat': 36.528539, 'lng': 34.289377},
#   'city': 'Mersin',
#   'district': 'Erdemli',
#   'average_stay_minutes': 150,
#   'average_spend': {'amount': 50, 'currency': 'TRY'},
#   'best_visit_times': {'season': ['Kış', 'Sonbahar'],
#    'days': ['Her gün'],
#    'hours': ['09:00-20:00']},
#   'tags': ['manzara', 'doğa', 'fotoğraf'],
#   'popularity_score': 72,
#   'virality_trend': 'yükselişte',
#   'average_rating': 4.6,
#   'review_count': 6833,
#   'sources': ['Wikipedia', 'TripAdvisor'],
#   'photos': ['https://en.wikipedia.org/wiki/Local_Beach_100']}]

# %%
len(json_files)
# Out:
# 480

# %%
from collections import Counter

Counter([item["city"] for item in json_files])
# Out:
# Counter({'Adana': 23,
#          'Ankara': 60,
#          'Antalya': 42,
#          'Gaziantep': 50,
#          'Bursa': 50,
#          'Diyarbakır': 10,
#          'İstanbul': 40,
#          'İzmir': 25,
#          'Kayseri': 10,
#          'Konya': 70,
#          'Mersin': 100})

# %%
with open("example_location.json", "r", encoding="utf-8") as f:
    example_location = json.load(f)
keys = set(example_location.keys())
keys
# Out:
# {'average_rating',
#  'average_spend',
#  'average_stay_minutes',
#  'best_visit_times',
#  'category',
#  'city',
#  'coordinates',
#  'district',
#  'id',
#  'name',
#  'photos',
#  'popularity_score',
#  'review_count',
#  'sources',
#  'tags',
#  'virality_trend'}

# %%
for json_file in json_files:
    # Tüm keyler uyuyor mu?
    assert keys == set(json_file.keys())

# %%
with open("data/final_data.json", "w", encoding="utf-8") as f:
    json.dump(json_files, f, ensure_ascii=False, indent=2)
